# %% [markdown]
# ----------------------------------------------------------
#          💸 DASHBOARD DE FINANZAS PERSONALES
# ----------------------------------------------------------
# ###### [Subir Archivo]  (CSV/Excel)
#
# ###### [+ Añadir movimiento manual] (opcional)
# ----------------------------------------------------------

# %% [markdown]
# Archivo cargado: Finance Transaction V_2.xlsx
#
# Transacciones procesadas: 347
#
# Rango de fechas: 2023-01-01 → 2023-12-31

# %% [markdown]
# ----------------------------------------------------------
# #### | Resumen | Categorías | Mensual | Instituciones| Buscador | Mapa | Predicción |
# ----------------------------------------------------------
